# %%
using Plots

# %%
f1(x) = sin(x) + tan(x);
f2(x) = cos(x) + cot(x);

# %%
Plots.plot!(f1,0:0.1:2, color = "black", label = "sin + tan")
Plots.plot!(f2,0:0.1:2, color = "black", label = "cos + cot", ls = :dash)
