# %%
using Plots

# %%
p1 = Plots.plot(exp, 0:1:100, color="black");
p2 = Plots.plot(log, 0:1:100, color="black", ls = :dash);

# %%
Plots.plot(p1,p2, layout=(1,2),label=["exp(x)" "ln(x)"], title=["a" "b"])
